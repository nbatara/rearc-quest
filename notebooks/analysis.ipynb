# %% [markdown]
# # Rearc Quest Analytics Notebook
#
# This notebook documents the analytics queries from Part 3 using pandas and duckdb.
# Fill in the cells with S3 download steps and DataFrame exploration as you iterate.

# %%
print("hello world")
# Out:
# hello world
